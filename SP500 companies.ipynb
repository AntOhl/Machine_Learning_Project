# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
companies = pd.read_excel('SP500_companies.xlsx')

# %%
companies
# Out:
#                          Ticker  \
# 0                             A
# 1                           AAL
# 2                           AAP
# 3                          AAPL
# 4                          ABBV
# ..                          ...
# 502                         ZBH
# 503                        ZION
# 504                         ZTS
# 505  Data Provided by IEX Cloud
# 506  Data updated on 2019-11-26
#
#                                                   Name   Price  \
# 0                           Agilent Technologies, Inc.   80.26
# 1                        American Airlines Group, Inc.   28.99
# 2                             Advance Auto Parts, Inc.  159.15
# 3                                          Apple, Inc.  266.37
# 4                                         AbbVie, Inc.   87.76
# ..                                                 ...     ...
# 502                       Zimmer Biomet Holdings, Inc.  145.08
# ...

# %%
companies_sorted = companies.sort_values(by=['Market Cap ($M)'])

# %%
plt.style.use('dark_background')
companies_sorted['Market Cap ($M)'].plot.bar(color = 'orange', figsize = (20, 7))
plt.title('S&P500 Market Cap Distribution', fontsize = 30, fontweight = 20)
plt.xlabel('Name of Companies')
plt.ylabel('Market Cap')
plt.show()

# %%
is_large = companies['Market Cap ($M)'] > 180000

# %%
companies_large = companies[is_large]
companies_large
# Out:
#     Ticker                          Name    Price  Dividend Yield  \
# 3     AAPL                   Apple, Inc.   266.37        0.011263
# 39    AMZN              Amazon.com, Inc.  1773.84             NaN
# 59      BA                The Boeing Co.   373.13        0.021105
# 60     BAC         Bank of America Corp.    33.47        0.018823
# 75   BRK.B      Berkshire Hathaway, Inc.   219.06             NaN
# 104  CMCSA                 Comcast Corp.    43.35        0.018916
# 121   CSCO           Cisco Systems, Inc.    45.45        0.030363
# 129    CVX                 Chevron Corp.   118.38        0.039618
# 140    DIS           The Walt Disney Co.   149.69        0.011758
# 181     FB                Facebook, Inc.   199.79             NaN
# 208   GOOG                Alphabet, Inc.  1306.69             NaN
# 209  GOOGL                Alphabet, Inc.  1305.64             NaN
# 222     HD          The Home Depot, Inc.   218.40        0.023397
# ...

# %%
companies_large = companies_large.Name.apply(lambda x : x.replace(' Inc.',""))
companies_large
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-85994fc69906> in <module>
# ----> 1 companies_large = companies_large.Name.apply(lambda x : x.replace(' Inc.',""))
#       2 companies_large
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'Name'

# %%
companies_large = companies_large.apply(lambda x : x.replace(' Corp.',""))
companies_large
# Out:
# 3                       Apple,
# 39                 Amazon.com,
# 59              The Boeing Co.
# 60             Bank of America
# 75         Berkshire Hathaway,
# 104                    Comcast
# 121             Cisco Systems,
# 129                    Chevron
# 140        The Walt Disney Co.
# 181                  Facebook,
# 208                  Alphabet,
# 209                  Alphabet,
# 222            The Home Depot,
# 248                      Intel
# 264          Johnson & Johnson
# 266            JPMorgan Chase.
# 277          The Coca-Cola Co.
# 301                Mastercard,
# 324                    Merck.,
# 328                  Microsoft
# 359                     Oracle
# 366                   PepsiCo,
# 367                     Pfizer
# 369       Procter & Gamble Co.
# 432                      AT&T,
# 458        UnitedHealth Group,
# 465                      Visa,
# 476    Verizon Communications,
# 484               Wells Fargo.
# 489                   Walmart,
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(' & Co',''))
companies_large
# Out:
# 3                       Apple,
# 39                 Amazon.com,
# 59              The Boeing Co.
# 60             Bank of America
# 75         Berkshire Hathaway,
# 104                    Comcast
# 121             Cisco Systems,
# 129                    Chevron
# 140        The Walt Disney Co.
# 181                  Facebook,
# 208                  Alphabet,
# 209                  Alphabet,
# 222            The Home Depot,
# 248                      Intel
# 264          Johnson & Johnson
# 266            JPMorgan Chase.
# 277          The Coca-Cola Co.
# 301                Mastercard,
# 324                    Merck.,
# 328                  Microsoft
# 359                     Oracle
# 366                   PepsiCo,
# 367                     Pfizer
# 369       Procter & Gamble Co.
# 432                      AT&T,
# 458        UnitedHealth Group,
# 465                      Visa,
# 476    Verizon Communications,
# 484               Wells Fargo.
# 489                   Walmart,
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(' Co.',''))
companies_large
# Out:
# 3                       Apple,
# 39                 Amazon.com,
# 59                  The Boeing
# 60             Bank of America
# 75         Berkshire Hathaway,
# 104                    Comcast
# 121             Cisco Systems,
# 129                    Chevron
# 140            The Walt Disney
# 181                  Facebook,
# 208                  Alphabet,
# 209                  Alphabet,
# 222            The Home Depot,
# 248                      Intel
# 264          Johnson & Johnson
# 266            JPMorgan Chase.
# 277              The Coca-Cola
# 301                Mastercard,
# 324                    Merck.,
# 328                  Microsoft
# 359                     Oracle
# 366                   PepsiCo,
# 367                     Pfizer
# 369           Procter & Gamble
# 432                      AT&T,
# 458        UnitedHealth Group,
# 465                      Visa,
# 476    Verizon Communications,
# 484               Wells Fargo.
# 489                   Walmart,
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace('The ',''))
companies_large
# Out:
# 3                       Apple,
# 39                 Amazon.com,
# 59                      Boeing
# 60             Bank of America
# 75         Berkshire Hathaway,
# 104                    Comcast
# 121             Cisco Systems,
# 129                    Chevron
# 140                Walt Disney
# 181                  Facebook,
# 208                  Alphabet,
# 209                  Alphabet,
# 222                Home Depot,
# 248                      Intel
# 264          Johnson & Johnson
# 266            JPMorgan Chase.
# 277                  Coca-Cola
# 301                Mastercard,
# 324                    Merck.,
# 328                  Microsoft
# 359                     Oracle
# 366                   PepsiCo,
# 367                     Pfizer
# 369           Procter & Gamble
# 432                      AT&T,
# 458        UnitedHealth Group,
# 465                      Visa,
# 476    Verizon Communications,
# 484               Wells Fargo.
# 489                   Walmart,
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(',',''))
companies_large
# Out:
# 3                       Apple
# 39                 Amazon.com
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121             Cisco Systems
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266           JPMorgan Chase.
# 277                 Coca-Cola
# 301                Mastercard
# 324                    Merck.
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458        UnitedHealth Group
# 465                      Visa
# 476    Verizon Communications
# 484              Wells Fargo.
# 489                   Walmart
# 497               Exxon Mobil
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace('.com',''))
companies_large
# Out:
# 3                       Apple
# 39                     Amazon
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121             Cisco Systems
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266           JPMorgan Chase.
# 277                 Coca-Cola
# 301                Mastercard
# 324                    Merck.
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458        UnitedHealth Group
# 465                      Visa
# 476    Verizon Communications
# 484              Wells Fargo.
# 489                   Walmart
# 497               Exxon Mobil
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace('.',''))
companies_large
# Out:
# 3                       Apple
# 39                     Amazon
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121             Cisco Systems
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266            JPMorgan Chase
# 277                 Coca-Cola
# 301                Mastercard
# 324                     Merck
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458        UnitedHealth Group
# 465                      Visa
# 476    Verizon Communications
# 484               Wells Fargo
# 489                   Walmart
# 497               Exxon Mobil
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(' Group',''))
companies_large
# Out:
# 3                       Apple
# 39                     Amazon
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121             Cisco Systems
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266            JPMorgan Chase
# 277                 Coca-Cola
# 301                Mastercard
# 324                     Merck
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458              UnitedHealth
# 465                      Visa
# 476    Verizon Communications
# 484               Wells Fargo
# 489                   Walmart
# 497               Exxon Mobil
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(' Systems',''))
companies_large
# Out:
# 3                       Apple
# 39                     Amazon
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121                     Cisco
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266            JPMorgan Chase
# 277                 Coca-Cola
# 301                Mastercard
# 324                     Merck
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458              UnitedHealth
# 465                      Visa
# 476    Verizon Communications
# 484               Wells Fargo
# 489                   Walmart
# 497               Exxon Mobil
# ...

# %%
companies_large = companies_large.apply(lambda x : x.replace(' Mobil',''))
companies_large
# Out:
# 3                       Apple
# 39                     Amazon
# 59                     Boeing
# 60            Bank of America
# 75         Berkshire Hathaway
# 104                   Comcast
# 121                     Cisco
# 129                   Chevron
# 140               Walt Disney
# 181                  Facebook
# 208                  Alphabet
# 209                  Alphabet
# 222                Home Depot
# 248                     Intel
# 264         Johnson & Johnson
# 266            JPMorgan Chase
# 277                 Coca-Cola
# 301                Mastercard
# 324                     Merck
# 328                 Microsoft
# 359                    Oracle
# 366                   PepsiCo
# 367                    Pfizer
# 369          Procter & Gamble
# 432                      AT&T
# 458              UnitedHealth
# 465                      Visa
# 476    Verizon Communications
# 484               Wells Fargo
# 489                   Walmart
# 497                     Exxon
# ...

# %%
maincompanies = companies_large

# %%
maincompanies.to_csv('maincompanies')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
